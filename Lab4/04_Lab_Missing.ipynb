# %%
#Import Python Libraries
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Missing Values

# %%
#flights = pd.read_csv("d:/flights.csv")
flights =  pd.read_csv("flights.csv")
flights.head()
# Out:
#    year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier tailnum  \
# 0  2013      1    1     517.0        2.0     830.0       11.0      UA  N14228
# 1  2013      1    1     533.0        4.0     850.0       20.0      UA  N24211
# 2  2013      1    1     542.0        2.0     923.0       33.0      AA  N619AA
# 3  2013      1    1     554.0       -6.0     812.0      -25.0      DL  N668DN
# 4  2013      1    1     554.0       -4.0     740.0       12.0      UA  N39463
#
#    flight origin dest  air_time  distance  hour  minute
# 0    1545    EWR  IAH     227.0      1400   5.0    17.0
# 1    1714    LGA  IAH     227.0      1416   5.0    33.0
# 2    1141    JFK  MIA     160.0      1089   5.0    42.0
# 3     461    LGA  ATL     116.0       762   5.0    54.0
# 4    1696    EWR  ORD     150.0       719   5.0    54.0

# %%
# เลือกข้อมูลที่มี missing value (use isnull()) อย่างน้อย 1 ตัว (use .any(axis=1)) ในแต่ละแถว 
# df[df.method()]

#your code
#flights.isnull().sum()
df_miss = flights[flights.isnull().any(axis=1)]
df_miss
# Out:
#         year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 330     2013      1    1    1807.0       29.0    2251.0        NaN      UA
# 403     2013      1    1       NaN        NaN       NaN        NaN      AA
# 404     2013      1    1       NaN        NaN       NaN        NaN      AA
# 855     2013      1    2    2145.0       16.0       NaN        NaN      UA
# 858     2013      1    2       NaN        NaN       NaN        NaN      AA
# 859     2013      1    2       NaN        NaN       NaN        NaN      AA
# 860     2013      1    2       NaN        NaN       NaN        NaN      UA
# 1067    2013      1    3    1348.0       -2.0    1821.0        NaN      DL
# 1275    2013      1    3       NaN        NaN       NaN        NaN      AA
# 1276    2013      1    3       NaN        NaN       NaN        NaN      AA
# 1277    2013      1    3       NaN        NaN       NaN        NaN      AA
# ...

# %%
# เลือก arr_delay ที่มีค่า missing value
flights1 = flights[flights['arr_delay'].isnull()]
flights1.head()
# Out:
#      year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 330  2013      1    1    1807.0       29.0    2251.0        NaN      UA
# 403  2013      1    1       NaN        NaN       NaN        NaN      AA
# 404  2013      1    1       NaN        NaN       NaN        NaN      AA
# 855  2013      1    2    2145.0       16.0       NaN        NaN      UA
# 858  2013      1    2       NaN        NaN       NaN        NaN      AA
#
#     tailnum  flight origin dest  air_time  distance  hour  minute
# 330  N31412    1228    EWR  SAN       NaN      2425  18.0     7.0
# 403  N3EHAA     791    LGA  DFW       NaN      1389   NaN     NaN
# 404  N3EVAA    1925    LGA  MIA       NaN      1096   NaN     NaN
# 855  N12221    1299    EWR  RSW       NaN      1068  21.0    45.0
# 858     NaN     133    JFK  LAX       NaN      2475   NaN     NaN

# %%
# เลือกข้อมูลทั้งหมดที่ไม่มี missing value (use dropna())
flights2_nomissing = flights.dropna()
flights2_nomissing.head(10)
# Out:
#    year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier tailnum  \
# 0  2013      1    1     517.0        2.0     830.0       11.0      UA  N14228
# 1  2013      1    1     533.0        4.0     850.0       20.0      UA  N24211
# 2  2013      1    1     542.0        2.0     923.0       33.0      AA  N619AA
# 3  2013      1    1     554.0       -6.0     812.0      -25.0      DL  N668DN
# 4  2013      1    1     554.0       -4.0     740.0       12.0      UA  N39463
# 5  2013      1    1     558.0       -2.0     753.0        8.0      AA  N3ALAA
# 6  2013      1    1     558.0       -2.0     924.0        7.0      UA  N29129
# 7  2013      1    1     558.0       -2.0     923.0      -14.0      UA  N53441
# 8  2013      1    1     559.0       -1.0     941.0       31.0      AA  N3DUAA
# 9  2013      1    1     559.0       -1.0     854.0       -8.0      UA  N76515
#
#    flight origin dest  air_time  distance  hour  minute
# ...

# %%
flights2_nomissing.isnull().sum()
#ใช้สำหรับเช็คว่ายังมีค่า null อยู่ไหม
# Out:
# year         0
# month        0
# day          0
# dep_time     0
# dep_delay    0
# arr_time     0
# arr_delay    0
# carrier      0
# tailnum      0
# flight       0
# origin       0
# dest         0
# air_time     0
# distance     0
# hour         0
# minute       0
# dtype: int64

# %%
flights.shape
# Out:
# (160754, 16)

# %%
flights2_nomissing.shape
#ข้อมูลที่ลบค่า null ไปแล้ว
# Out:
# (157927, 16)

# %%
# เปลี่ยนค่า missing values ของ dep_delay ด้วยค่าศูนย์ (use fillna(value))
nomiss = flights['dep_delay'].fillna(0)
nomiss.isnull().sum()

# ตรวจสอบว่า nomiss เป็น null หรือไม่ (use isnull()) จะให้ค่า True or False (any()) ถ้าเป็น null จะมีค่าเป็น true

#your code
# Out:
# 0

# %%
# เปลี่ยนค่า missing values  (use fillna(value) )ของ dep_delay ด้วยค่าเฉลี่ยของ dep_delay
#หรือจะใช้คำสั่ง mean_dep_delay = np.mean(flights['dep_delay'])

mean_dep_delay = flights['dep_delay'].fillna(flights['dep_delay'].mean())

print("ค่าเฉลี่ยของ dep_delay",mean_dep_delay.mean())

average_nomiss = flights.fillna(mean_dep_delay)
# Out:
# ค่าเฉลี่ยของ dep_delay 9.463773056092277

# %%
average_nomiss
# Out:
#         year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 0       2013      1    1     517.0        2.0     830.0       11.0      UA
# 1       2013      1    1     533.0        4.0     850.0       20.0      UA
# 2       2013      1    1     542.0        2.0     923.0       33.0      AA
# 3       2013      1    1     554.0       -6.0     812.0      -25.0      DL
# 4       2013      1    1     554.0       -4.0     740.0       12.0      UA
# 5       2013      1    1     558.0       -2.0     753.0        8.0      AA
# 6       2013      1    1     558.0       -2.0     924.0        7.0      UA
# 7       2013      1    1     558.0       -2.0     923.0      -14.0      UA
# 8       2013      1    1     559.0       -1.0     941.0       31.0      AA
# 9       2013      1    1     559.0       -1.0     854.0       -8.0      UA
# 10      2013      1    1     602.0       -8.0     812.0       -8.0      DL
# ...

# %%
# นับจำนวน missing values (use sum()) ที่อยู่ในแต่ละ dep_delay, arr_delay attribute

# your code

# %%
#นับจำนวน missing value ของ dep_delay และ arr_delay ทั้งหมด

# your code
flights['dep_delay'].fillna(0).count()
flights['dep_delay'].count()
# Out:
# 158418

# %% [markdown]
# ---
# ### Common Aggregation Functions:
#
# |Function|Description
# |-------|--------
# |min   | minimum
# |max   | maximum
# |count   | number of non-null observations
# |sum   | sum of values
# |mean  | arithmetic mean of values
# |median | median
# |mad | mean absolute deviation
# |mode | mode
# |prod   | product of values
# |std  | standard deviation
# |var | unbiased variance

# %%
# Find the number of non-missing values in each column
# นับจำนวนที่ไม่ใช่ missing value ของแต่ละ attribute

# your code

# %%
# Find minimum value for all the columns in the dataset

# your code

# %%
#หาค่าเฉลี่ยของ (use .mean()) dep_delay แยกตามกลุ่ม carrier (use groupby())

# your code

# %%
#ใช้ agg() method เพื่อหา min, max, mean  ของ dep_delay,arr_delay

# your code
flights.agg(['min','max'])
# Out:
#      year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# min  2013      1    1       1.0      -33.0       1.0      -75.0      AA
# max  2013     12   31    2400.0     1014.0    2400.0     1007.0      US
#
#      flight origin dest  air_time  distance  hour  minute
# min       1    EWR  ANC      21.0        17   0.0     0.0
# max    2599    LGA  TPA     695.0      4963  24.0    59.0

# %% [markdown]
# ### Basic descriptive statistics

# %% [markdown]
# |Function|Description
# |-------|--------
# |min   | minimum
# |max   | maximum
# |mean  | arithmetic mean of values
# |median | median
# |mad | mean absolute deviation
# |mode | mode
# |std  | standard deviation
# |var | unbiased variance
# |sem | standard error of the mean
# |skew| sample skewness
# |kurt|kurtosis
# |quantile| value at %

# %%
# คำนวณหาค่าสถิติพื้นฐานของ dep_delay (use describe())

# your code

# %%
# Count the number of records for each different value in a vector
#เหมือน flights.groupby('carrier')['carrier'].count()  (use value_counts() )

# your code
flights['dep_delay'].value_counts()
# Out:
# -4.0       13053
# -3.0       12987
# -5.0       12931
# -2.0       11667
# -6.0       10582
# -1.0        9973
#  0.0        8535
# -7.0        8093
# -8.0        5365
#  1.0        4647
#  2.0        3554
# -9.0        3376
#  3.0        3001
#  4.0        2574
#  5.0        2314
#  6.0        1959
# -10.0       1958
#  7.0        1809
#  8.0        1678
#  9.0        1527
#  10.0       1330
#  11.0       1321
#  12.0       1166
#  13.0       1123
# -11.0       1080
#  14.0       1045
#  15.0       1002
#  16.0        939
#  17.0        838
#  18.0        823
#            ...
#  382.0         1
#  845.0         1
#  352.0         1
#  466.0         1
#  410.0         1
#  269.0         1
#  545.0         1
#  426.0         1
#  797.0         1
#  454.0         1
#  447.0         1
#  261.0         1
#  660.0         1
#  398.0         1
#  333.0         1
#  338.0         1
#  788.0         1
#  803.0         1
#  321.0         1
# -33.0          1
#  696.0         1
# ...

# %%
# use count()
